# %%
import json
from sentence_transformers import SentenceTransformer
from sklearn.cluster import KMeans
import numpy as np
import re

# 加载 BERT 模型
model = SentenceTransformer('all-MiniLM-L6-v2')

def extract_keywords(text, top_n=5):
    # 简单分句（可用更好分词器替换）
    words = re.findall(r'\b\w+\b', text)
    unique_words = list(set(words))

    # 生成每个词的向量
    embeddings = model.encode(unique_words)
    
    # 聚类
    if len(unique_words) < top_n:
        return unique_words
    kmeans = KMeans(n_clusters=top_n)
    kmeans.fit(embeddings)
    
    # 取每个簇的中心词
    cluster_centers = kmeans.cluster_centers_
    closest_words = []
    for center in cluster_centers:
        distances = np.linalg.norm(embeddings - center, axis=1)
        closest_index = np.argmin(distances)
        closest_words.append(unique_words[closest_index])
    
    return closest_words

# 加载你的 JSON 数据
with open("papers_standardized.json", "r") as f:
    data = json.load(f)

for paper in data:
    abstract = paper.get("abstract", "")
    keywords = extract_keywords(abstract)
    print(f"Paper ID: {paper['paper_id']}")
    print(f"Title: {paper['title']}")
    print(f"Keywords: {keywords}")
    print("-" * 40)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Paper ID: 9203077
# Title: Finite W-algebras
# Keywords: ['versions', '2', 'reducible', 'In', 'is']
# ----------------------------------------
# Paper ID: 9203063
# Title: The Spectrum of Sl(2, R)/U(1) Black Hole Conformal Field Theory
# Keywords: ['described', 'form', 'of', 'a', 'vertex']
# ----------------------------------------
# Paper ID: 9212146
# Title: Charged black holes in effective string theory
# Keywords: ['hole', 'show', 'of', 'action', 'a']
# ----------------------------------------
# Paper ID: 9204042
# Title: Asymptotic Behavior of 2-d Black Holes
# Keywords: ['large', 'field', 'the', 'with', 'consider']
# ----------------------------------------
# Paper ID: 9210037
# Title: Generalized Drinfeld-Sokolov Reductions and KdV Type Hierarchies
# Keywords: ['approach', 'in', 'that', 'generated', 'a']
# ----------------------------------------
# Paper ID: 9210023
# Title: Infinite Braided Tensor Products and 2-D quantum Gravity
# Keywords: ['that', 'in', 'group', 'also', 'used']
# ----------------------------------------
# Paper ID: 9204056
# Title: Chern-Simons Solitons, Toda Theories and the Chiral Model
# Keywords: ['matter', 'of', 'SU', 'classification', 'equations']
# ----------------------------------------
# Paper ID: 9212152
# Title: Unimodality of generalized Gaussian coefficients
# Keywords: ['unimodality', 'of', 'coefficients', 'generalized', 'Kostka']
# ----------------------------------------
# Paper ID: 9204081
# Title: Signature Characters for the Virasoro Algebra
# Keywords: ['number', 'These', 'a', 'unitary', 'characters']
# ----------------------------------------
# Paper ID: 9204095
# Title: Physical States in G/G Models and 2d Gravity
# Keywords: ['corresponding', 'of', 'case', 'model', 'q']
# ----------------------------------------
# Paper ID: 9211117
# Title: Black Extended Objects, Naked Singularities and P-Branes
# Keywords: ['show', 'like', 'number', 'a', 'the']
# ----------------------------------------
# Paper ID: 9207013
# Title: On the two-boson picture of the KP hierarchy
# Keywords: ['almost', 'A', 'in', 'it', 'for']
# ----------------------------------------
# Paper ID: 9207007
# Title: A New Solution of the Supersymmetric TJ Model by Means of the Quantum Inverse Scattering Method
# Keywords: ['spin', 'the', 'expressions', 'of', 'Method']
# ----------------------------------------
# Paper ID: 9211103
# Title: The Ashtekar Formalism and WKB Wave Functions of N=1,2 Supergravities
# Keywords: ['1', 'functional', 'the', 'cosmological', 'supersymmetric']
# ----------------------------------------
# Paper ID: 9209002
# Title: A geometrical interpretation of classical W-transformations
# Keywords: ['two', 'dimensional', 'of', 'deformations', 'phase']
# ----------------------------------------
# Paper ID: 9209016
# Title: Quantization of Dyon Charge and Electric-Magnetic Duality in String Theory
# Keywords: ['to', 'theory', 'the', 'angle', 'constant']
# ----------------------------------------
# Paper ID: 9205016
# Title: Duality and $O(d,d)$ Symmetries in String Theory
# Keywords: ['bosonic', 'A', 'of', 'dual', 'coordinates']
# ----------------------------------------
# Paper ID: 9211063
# Title: Topological Conformal Gravity in Four Dimensions
# Keywords: ['Such', 'complex', 'is', 'in', 'that']
# ----------------------------------------
# Paper ID: 9211077
# Title: Quantum algebras and Lie groups
# Keywords: ['algebras', 'in', 'is', 'group', 'The']
# ----------------------------------------
# Paper ID: 9205002
# Title: Fusion Rules for the q-deformed Vertex Operators of U_q(sl(2)^)
# Keywords: ['U_q', 'we', 'operators', 'of', 'Reshetikhin']
# ----------------------------------------
# Paper ID: 9202023
# Title: The Emergence of Radiation from Gravitational Potential Wells: The Absence of $\omega M$ Effects
# Keywords: ['related', 'not', '2', 'wave', 'from']
# ----------------------------------------
# Paper ID: 9202037
# Title: Splitting of an Extremal Reissner-Nordstr\"om Throat via Quantum Tunneling
# Keywords: ['Nordstr', 'the', 'describing', 'with', 'an']
# ----------------------------------------
# Paper ID: 9211088
# Title: Gauge Conditions for the Constrained-WZNW--Toda Reductions
# Keywords: ['semi', 'solutions', 'the', 'expansion', 'of']
# ----------------------------------------
# Paper ID: 9208056
# Title: Semiclassical Quantization of Two-Dimensional Dilaton Gravity
# Keywords: ['theories', 'of', 'compute', 'result', 'Riemann']
# ----------------------------------------
# Paper ID: 9201072
# Title: Quantum Rings and Recursion Relations in 2D Quantum Gravity
# Keywords: ['a', 'on', 'of', 'corresponding', 'one']
# ----------------------------------------
# Paper ID: 9201066
# Title: Interaction of Tachyons and Discrete States in c=1 2-D Quantum Gravity
# Keywords: ['Metropolitan', 'a', 'This', 'in', 'couplings']
# ----------------------------------------
# Paper ID: 9208042
# Title: Strings in Discrete and Continuous Target Spaces: A Comparison
# Keywords: ['different', 'of', 'approach', 'discrete', 'correlators']
# ----------------------------------------
# Paper ID: 9206047
# Title: Addendum to ``Integrability of Open Spin Chains with Quantum Algebra Symmetry''
# Keywords: ['algebra', 'A', 'that', 'n', 'with']
# ----------------------------------------
# Paper ID: 9212032
# Title: 3D-Ising Model as a String Theory in Three Dimentional Euclidean Space
# Keywords: ['Pott', 'are', 'the', 'model', 'two']
# ----------------------------------------
# Paper ID: 9210143
# Title: The $W$ algebra structure of $N=2$ $CP_{n}$ coset models
# Keywords: ['Theory', 'Rome', 'of', 'n', 'quantum']
# ----------------------------------------
# Paper ID: 9210157
# Title: q-deformed conformal and Poincar{\'e} algebras on quantum 4-spinors
# Keywords: ['algebra', '2', 'q', 'constructed', 'of']
# ----------------------------------------
# Paper ID: 9212026
# Title: Geodesic Scattering of Solitonic Strings
# Keywords: ['for', 'string', 'the', 'solitons', 'dynamical']
# ----------------------------------------
# Paper ID: 9206053
# Title: On Correlation Functions for Non-critical Strings with c<1 but d>1
# Keywords: ['calculation', 'the', 'space', 'structure', 'Various']
# ----------------------------------------
# Paper ID: 9208081
# Title: c = 1 Two Dimensional Quantum Gravity
# Keywords: ['of', 'finding', 'computed', 'field', 'theory']
# ----------------------------------------
# Paper ID: 9206084
# Title: Closed String Field Theory: Quantum Action and the BV Master Equation
# Keywords: ['foliated', 'detail', 'constructed', 'of', 'algebra']
# ----------------------------------------
# Paper ID: 9206090
# Title: Polynomial averages in the Kontsevich model
# Keywords: ['the', 'functions', 'powers', 'with', 'measure']
# ----------------------------------------
# Paper ID: 9206091
# Title: Integrable Superhierarchy of Discretized 2d Supergravity
# Keywords: ['scaled', 'constraints', 'described', 'from', 'the']
# ----------------------------------------
# Paper ID: 9206085
# Title: A New Construction of the Penner Model
# Keywords: ['integral', 'of', 'matrix', 'the', 'related']
# ----------------------------------------
# Paper ID: 9208080
# Title: Correlation Functions in Two-Dimensional Dilaton Gravity
# Keywords: ['is', 'matter', 'approach', '1', 'for']
# ----------------------------------------
# Paper ID: 9210156
# Title: Quantizing Effective Strings
# Keywords: ['the', 'in', 'theory', 'are', 'consistent']
# ----------------------------------------
# Paper ID: 9206052
# Title: Staircase Models from Affine Toda Field Theory
# Keywords: ['conjectured', 'A', 'equations', 'turn', 'analytic']
# ----------------------------------------
# Paper ID: 9212027
# Title: A Time-Dependent Classical Solution of C=1 String Field Theory and Non-Perturbative Effects
# Keywords: ['hole', 'and', 'fermion', 'a', 'q']
# ----------------------------------------
# Paper ID: 9212033
# Title: On the Breakdown of Perturbation Theory
# Keywords: ['particles', 'Induced', 'the', 'of', 'exponentially']
# ----------------------------------------
# Paper ID: 9206046
# Title: Integrable Systems for Particles with Internal Degrees of Freedom
# Keywords: ['functions', 'some', 'of', 'This', 'dependent']
# ----------------------------------------
# Paper ID: 9210142
# Title: Recent Efforts in the Computation of String Couplings:
# Keywords: ['Picard', 'are', 'advances', 'computation', 'symmetry']
# ----------------------------------------
# Paper ID: 9201067
# Title: Exact S-Matrices for Nonsimply-Laced Affine Toda Theories
# Keywords: ['derive', 'for', 'laced', 'algebras', 'the']
# ----------------------------------------
# Paper ID: 9208043
# Title: Diffeomorphism group and conformal fields
# Keywords: ['constructed', 'The', 'are', 'tensor', 'more']
# ----------------------------------------
# Paper ID: 9208057
# Title: Affine Toda Solitons and Automorphisms of Dynkin Diagrams
# Keywords: ['diagrams', 'to', 'of', 'solutions', 'affine']
# ----------------------------------------
# Paper ID: 9201073
# Title: All-orders wormhole vertex operators from the Wheeler-deWitt equation
# Keywords: ['orders', 'and', 'in', 'equation', 'symmetric']
# ----------------------------------------
# Paper ID: 9211089
# Title: Novel Flows beteen N=2 Landau-Ginzburg Theories: New Directions in Moduli Space via c=0 Theories
# Keywords: ['method', 'the', 'In', 'an', 'pairs']
# ----------------------------------------
# Paper ID: 9202036
# Title: Holonomy groups and W-symmetries
# Keywords: ['the', 'arise', 'supersymmetries', 'for', 'algebra']
# ----------------------------------------
# Paper ID: 9202022
# Title: Recent Developments in Non-Perturbative Quantum Gravity
# Keywords: ['theory', 'of', 'regions', 'geometrical', 'measurements']
# ----------------------------------------
# Paper ID: 9205003
# Title: Reality in the Differential Calculus on q-euclidean Spaces
# Keywords: ['real', 'derivatives', 'of', 'structure', 'the']
# ----------------------------------------
# Paper ID: 9211076
# Title: Thermal Green's Functions from Quantum Mechanical Path Integrals
# Keywords: ['thermal', 'computed', 'With', 'a', 'integrals']
# ----------------------------------------
# Paper ID: 9211062
# Title: Clifford Algebra Derivation of the Characteristic Hypersurfaces of Maxwell's Equations
# Keywords: ['signal', 'the', 'equations', 'of', 'Maxwell']
# ----------------------------------------
# Paper ID: 9205017
# Title: c = 1 conformal field theory and the fractional quantum Hall effect
# Keywords: ['FQHE', 'the', 'description', 'of', 'conformal']
# ----------------------------------------
# Paper ID: 9209017
# Title: The geometry of supersymmetric coset models and superconformal algebras
# Keywords: ['algebras', 'the', 'model', '4', 'supersymmetric']
# ----------------------------------------
# Paper ID: 9209003
# Title: Fermions in the Lowest Landau Level: Bosonization, $W_{\infty}$ Algebra, Droplets, Chiral Boson
# Keywords: ['1', 'fermionic', 'a', 'theory', 'In']
# ----------------------------------------
# Paper ID: 9207006
# Title: Exactly Solvable Models of 2d Dilaton Quantum Gravity
# Keywords: ['in', 'this', 'models', 'a', 'expanded']
# ----------------------------------------
# Paper ID: 9211102
# Title: Fermionic Quasi-Particle Representations for Characters of ${(G^{(1)})_1 \times (G^{(1)})_1 \o (G^{(1)})_2}$
# Keywords: ['of', 'particles', 'character', 'are', 'quasi']
# ----------------------------------------
# Paper ID: 9211116
# Title: CPT, Strings, and the $K \bar K$ System
# Keywords: ['an', 'In', 'our', 'spontaneous', 'for']
# ----------------------------------------
# Paper ID: 9207012
# Title: Classical Hamiltonian Reduction and Superconformal Algebras
# Keywords: ['gauge', 'of', 'superfields', 'representation', 'using']
# ----------------------------------------
# Paper ID: 9204094
# Title: N=2 Supersymmetry, Painleve III and Exact Scaling Functions in 2D Polymers
# Keywords: ['to', 'two', 'in', 'solution', 'that']
# ----------------------------------------
# Paper ID: 9204080
# Title: Scattering in Soliton Models and the Bosonic Exchange description
# Keywords: ['with', 'Our', 'amplitudes', 'is', 'a']
# ----------------------------------------
# Paper ID: 9204057
# Title: "Peireles Substitution" and Chern-Simons Quantum Mechanics
# Keywords: ['for', 'projection', 'a', 'lowest', 'Hamiltonian']
# ----------------------------------------
# Paper ID: 9210022
# Title: Comment on Gauge-Independent Analysis of Chern-Simons Theory with Matter Coupling
# Keywords: ['theory', 'and', 'of', 'relativistic', 'not']
# ----------------------------------------
# Paper ID: 9212153
# Title: Stringy Sphalerons and Non-Abelian Black Holes
# Keywords: ['sector', 'distinct', 'hole', 'of', 'spherically']
# ----------------------------------------
# Paper ID: 9212147
# Title: New Shape Invariant Potentials in Supersymmetric Quantum Mechanics
# Keywords: ['given', 'an', 'to', 'invariant', 'are']
# ----------------------------------------
# Paper ID: 9210036
# Title: Geometric Gravitational Forces on Particles Moving in a Line
# Keywords: ['dilaton', 'gravity', 'angle', 'the', 'In']
# ----------------------------------------
# Paper ID: 9204043
# Title: BRST-Fixed Points and Topological Conformal Symmetry
# Keywords: ['a', 'case', 'theory', 'Witten', '2']
# ----------------------------------------
# Paper ID: 9203062
# Title: A note on the KP hierarchy
# Keywords: ['hat', 'structure', 'Given', 'the', 'Hamiltonian']
# ----------------------------------------
# Paper ID: 9203076
# Title: Quantizing SL(N) Solitons and the Hecke Alegbra
# Keywords: ['where', 'a', 'theory', 'solution', 'and']
# ----------------------------------------
# Paper ID: 9203060
# Title: Classical Scattering in $1+1$ Dimensional String Theory
# Keywords: ['relations', 'we', 'a', 'backgrounds', 'models']
# ----------------------------------------
# Paper ID: 9204069
# Title: Ashtekar's Variables for Arbitrary Gauge Group
# Keywords: ['the', 'presented', 'of', 'canonical', 'gravity']
# ----------------------------------------
# Paper ID: 9203074
# Title: A cubic action for self-dual Yang-Mills
# Keywords: ['is', 'three', 'a', 'from', 'N']
# ----------------------------------------
# Paper ID: 9212151
# Title: Beyond Supersymmetry and Quantum Symmetry (an introduction to braided groups and braided matrices)
# Keywords: ['dimensional', 'product', 'so', 'Most', 'of']
# ----------------------------------------
# Paper ID: 9210020
# Title: On the Linearized Artin Braid Representation
# Keywords: ['group', 'given', 'and', 'linear', 'representations']
# ----------------------------------------
# Paper ID: 9204055
# Title: Covariant Phase Space Formulation of Parametrized Field Theories
# Keywords: ['space', 'studied', 'symplectic', 'the', 'issues']
# ----------------------------------------
# Paper ID: 9204041
# Title: Topological First-Order Systems with Landau-Ginzburg Interactions
# Keywords: ['correlation', 'to', 'models', 'twisting', 'b']
# ----------------------------------------
# Paper ID: 9210034
# Title: Thermal Equilibrium from the Hu-Paz-Zhang Master Equation
# Keywords: ['coupled', 'The', 'heat', 'oscillator', 'effectively']
# ----------------------------------------
# Paper ID: 9212145
# Title: The Theory of Turbulence in Two Dimensions
# Keywords: ['enstrophy', 'field', 'from', 'theory', 'of']
# ----------------------------------------
# Paper ID: 9203048
# Title: Quantum Galilei Group as Symmetry of Magnons
# Keywords: ['ansatz', 'algebra', 'of', 'the', 'magnon']
# ----------------------------------------
# Paper ID: 9204096
# Title: On the W-hair of String Black Holes and the Singularity Problem
# Keywords: ['the', 'with', 'four', 'a', 'space']
# ----------------------------------------
# Paper ID: 9204082
# Title: The $O(n)$ model on a random surface: critical points and large order behaviour
# Keywords: ['are', 'that', 'determine', 'regular', 'one']
# ----------------------------------------
# Paper ID: 9211100
# Title: Foundations of Rational Quantum Field Theory, I
# Keywords: ['Conformal', 'theory', 'ones', 'is', 'of']
# ----------------------------------------
# Paper ID: 9209029
# Title: A Note on the Algebraic Evaluation of Correlators in Local Chiral Conformal Field Theory
# Keywords: ['algebra', 'using', 'n', 'this', 'a']
# ----------------------------------------
# Paper ID: 9207004
# Title: d\leq1\bigcup d\geq25$ and Constrained KP Hierarchy from BRST Invariance in the $c\neq3$ Topological Algebra
# Keywords: ['representation', 'construction', '1', 'between', 'N']
# ----------------------------------------
# Paper ID: 9207010
# Title: Free Field Representations and Screening Operators for the $N=4$ Doubly Extended Superconformal Algebras
# Keywords: ['explicitly', 'This', 'algebra', 'for', 'A']
# ----------------------------------------
# Paper ID: 9211114
# Title: Boundary K-Matrices for the Six Vertex and the n(2n-1) A_{n-1} Vertex Models
# Keywords: ['solution', 'four', 'model', 'obtained', 'For']
# ----------------------------------------
# Paper ID: 9209015
# Title: Free Boson Representation of $q$-Vertex Operators and their Correlation Functions
# Keywords: ['q', 'function', 'A', 'bosonization', 'N']
# ----------------------------------------
# Paper ID: 9207038
# Title: Compensating Fields and Anomalies in Supergravity
# Keywords: ['formulation', 'are', 'considerations', 'theory', 'In']
# ----------------------------------------
# Paper ID: 9209001
# Title: Explicit Construction of Spin 4 Casimir Operator in the Coset Model $ \hat{SO} (5)_{1} \times \hat{SO} (5)_{m} / \hat{SO} (5)_{1+m} $
# Keywords: ['invariant', 'of', 'with', '1', 'series']
# ----------------------------------------
# Paper ID: 9211128
# Title: A classical N=4 super W_3 algebra
# Keywords: ['realized', 'a', 'super', 'form', '2']
# ----------------------------------------
# Paper ID: 9211074
# Title: Multivalued Fields on the Complex Plane and Braid Group Statistics
# Keywords: ['of', 'matrix', 'group', 'theory', 'the']
# ----------------------------------------
# Paper ID: 9205001
# Title: Classical Isomorphisms for Quantum Groups
# Keywords: ['matrices', 'of', '4', 'Sp', 'local']
# ----------------------------------------
# Paper ID: 9202008
# Title: Two Dimensional String Theory and the Topological Torus
# Keywords: ['gravity', 'The', '1', 'superring', 'analyze']
# ----------------------------------------
# Paper ID: 9205015
# Title: Conformal Symmetry and Central Charges in 4 Dimensions
# Keywords: ['well', '4', 'the', 'Wess', 'contribution']
# ----------------------------------------
# Paper ID: 9211060
# Title: On Macroscopic Energy Gap for $q$-Quantum Mechanical Systems
# Keywords: ['recently', 'Quantum', 'between', 'increases', 'the']
# ----------------------------------------
# Paper ID: 9211048
# Title: Rigorous Analysis of Renormalization Group Pathologies in the 4-State Clock Model
# Keywords: ['analysis', 'we', 'in', 'The', 'and']
# ----------------------------------------
# Paper ID: 9202034
# Title: Kinks in Finite Volume
# Keywords: ['theory', 'in', 'the', 'matrix', 'finite']
# ----------------------------------------
# Paper ID: 9202020
# Title: Thermodynamic Bethe Ansatz for G_k x G_l / G_{k+l} Coset Models Perturbed by Their \phi_{1,1,Adj} Operator
# Keywords: ['algebra', 'k', 'An', 'we', 'G_']
# ----------------------------------------
# Paper ID: 9205029
# Title: Neutrino Masses within the Minimal Supersymmetric Standard Model
# Keywords: ['4', 'coupling', 'mass', 'possibility', 'm_']
# ----------------------------------------
# Paper ID: 9208041
# Title: String fine tuning
# Keywords: ['hidden', 'model', 'prove', 'last', 'in']
# ----------------------------------------
# Paper ID: 9212019
# Title: Conformal Models of Two-Dimensional Turbulence
# Keywords: ['hierarchy', 'of', 'turbulence', 'concerning', 'physical']
# ----------------------------------------
# Paper ID: 9201065
# Title: Coupling of Tachyons and Discrete States in $c = 1$ 2-D Gravity
# Keywords: ['necessary', '2', 'dimensional', 'is', 'the']
# ----------------------------------------
# Paper ID: 9201071
# Title: SO(2,C) invariant ring structure of BRST cohomology and singular vectors in 2D gravity with c < 1 matter
# Keywords: ['for', 'M', 'SO', 'present', 'modules']
# ----------------------------------------
# Paper ID: 9206078
# Title: A Closed, Expanding Universe in String Theory
# Keywords: ['A', '4', 'of', 'space', 'conformal']
# ----------------------------------------
# Paper ID: 9208055
# Title: Putting String/Fivebrane Duality to the Test
# Keywords: ['To', 'result', 'be', 'D', '6']
# ----------------------------------------
# Paper ID: 9212025
# Title: Current-Current Singularities under External Gauge Fields
# Keywords: ['space', 'of', 'expansion', 'by', 'currents']
# ----------------------------------------
# Paper ID: 9206050
# Title: A New Approach to Lower Dimensional Gauge Theories
# Keywords: ['method', 'of', 'the', 'differential', 'impressively']
# ----------------------------------------
# Paper ID: 9210154
# Title: New Look at QED$_4$: the Photon as a Goldstone Boson and the Topological Interpretation of Electric Charge
# Keywords: ['vortex', 'of', 'therefore', 'a', 'infinite']
# ----------------------------------------
# Paper ID: 9201059
# Title: Quantum Hair on Black Holes
# Keywords: ['particle', 'of', 'model', 'examine', 'both']
# ----------------------------------------
# Paper ID: 9210140
# Title: Differential Renormalization of a Yukawa Model with $\gamma_5$
# Keywords: ['and', 'it', 'considered', 'gauge', 'dimension']
# ----------------------------------------
# Paper ID: 9206044
# Title: Conservation Laws and 2D Black Holes in Dilaton Gravity
# Keywords: ['a', 'motion', 'exists', 'obtained', 'that']
# ----------------------------------------
# Paper ID: 9208069
# Title: N=2 supersymmetric W-algebras
# Keywords: ['cal', 'algebras', 'supersymmetric', 'with', '2']
# ----------------------------------------
# Paper ID: 9212031
# Title: B\"acklund transformations for nonlinear evolution equations: Hilbert space approach
# Keywords: ['acklund', 'of', 'equations', 'A', 'approach']
# ----------------------------------------
# Paper ID: 9206093
# Title: Gauge Theories for Gravity on a Line
# Keywords: ['space', 'felt', 'my', 'with', 'goal']
# ----------------------------------------
# Paper ID: 9206087
# Title: Charged Dilatonic Black Hole and Hawking Radiation in Two Dimensions
# Keywords: ['describing', 'The', 'singularity', 'quantum', 'exist']
# ----------------------------------------
# Paper ID: 9206086
# Title: $N=\half$ Superstring in Zero Dimension and the Spontaneous Breakdown of the Supersymmetry
# Keywords: ['spontaneously', 'the', 'half', 'and', 'is']
# ----------------------------------------
# Paper ID: 9206092
# Title: Finite and Infinite Symmetries in (2+1)-Dimensional Field Theory
# Keywords: ['him', 'been', 'physics', 'in', 'Thus']
# ----------------------------------------
# Paper ID: 9210141
# Title: Braided Momentum Structure of the q-Poincare Group
# Keywords: ['structure', '1', 'product', 'but', 'for']
# ----------------------------------------
# Paper ID: 9212030
# Title: Supersymmetric String Waves
# Keywords: ['there', 'field', 'show', 'the', 'wave']
# ----------------------------------------
# Paper ID: 9208068
# Title: Dual formulation of classical W-algebras
# Keywords: ['an', 'extending', 'to', 'terms', 'superfields']
# ----------------------------------------
# Paper ID: 9206045
# Title: Concerning the Double Scaling Limit in the $O(N)$ Vector Model in Four-Dimensions
# Keywords: ['consistently', 'the', 'model', '1', 'O']
# ----------------------------------------
# Paper ID: 9206051
# Title: Gauged String Actions and O($\tilde{d}$, $\tilde{d}$) Transformation
# Keywords: ['ones', 'of', 'representation', 'ungauged', 'a']
# ----------------------------------------
# Paper ID: 9212024
# Title: Quarks as topological defects or what is confined inside a hadron?
# Keywords: ['fundamental', '2', 'However', 'of', 'model']
# ----------------------------------------
# Paper ID: 9201058
# Title: The Secret Chern-Simons Action for the Hot Gluon Plasma
# Keywords: ['a', 'with', 'given', 'determined', 'that']
# ----------------------------------------
# Paper ID: 9210155
# Title: Additional symmetries of KP, Grassmannian, and the string equation II
# Keywords: ['of', 'tau', 'the', 'modified', 'equations']
# ----------------------------------------
# Paper ID: 9201070
# Title: Induced $W_{\infty}$ Gravity as a WZNW Model
# Keywords: ['deformed', 'of', 'derive', 'a', 'gravity']
# ----------------------------------------
# Paper ID: 9208054
# Title: Continuum Limits of ``Induced QCD": Lessons of the Gaussian Model at d=1 and Beyond
# Keywords: ['present', 'analysis', 'in', 'However', '1']
# ----------------------------------------
# Paper ID: 9206079
# Title: Stringy Cosmic Strings and Axion Cohomology
# Keywords: ['corresponding', 'theory', 'The', 'present', 'solution']
# ----------------------------------------
# Paper ID: 9212018
# Title: 12j-symbols and four-dimensional quantum gravity
# Keywords: ['we', 'the', 'In', 'exponential', 'dimensional']
# ----------------------------------------
# Paper ID: 9208040
# Title: On the twisted G/H topological models
# Keywords: ['and', 'corresponding', 'N', 'the', 'charge']
# ----------------------------------------
# Paper ID: 9201064
# Title: Perturbing the Ground Ring of 2-D String Theory
# Keywords: ['theory', 'that', 'use', 'class', 'in']
# ----------------------------------------
# Paper ID: 9202021
# Title: The Master Equation of 2D String Theory
# Keywords: ['is', 'equation', 'in', 'the', 'of']
# ----------------------------------------
# Paper ID: 9205028
# Title: Fadeev-Popov Ghosts and 1+1 Dimensional Black Hole Evaporation
# Keywords: ['also', 'of', 'matter', 'arise', 'field']
# ----------------------------------------
# Paper ID: 9211049
# Title: Semiclassical Tunneling in 1+1 Dimensional String Theory
# Keywords: ['connecting', '1', 'of', 'contribution', 'description']
# ----------------------------------------
# Paper ID: 9202035
# Title: Remarks on the BRST-cohomology for $c_M > 1$ matter coupled to ``Liouville gravity"
# Keywords: ['Thus', '2', 'a', 'p_L', 'matter']
# ----------------------------------------
# Paper ID: 9211061
# Title: Finite sigma models and exact string solutions with Minkowski signature metric
# Keywords: ['Killing', 'of', 'corresponding', 'N', 'invariant']
# ----------------------------------------
# Paper ID: 9205014
# Title: Matrix Model Perturbed by Higher Order Curvature Terms
# Keywords: ['perturbed', 'with', 'the', 'terms', 'D']
# ----------------------------------------
# Paper ID: 9211075
# Title: Interaction and modular invariance of strings on curved manifolds
# Keywords: ['we', 'class', 'from', '14', '1']
# ----------------------------------------
# Paper ID: 9202009
# Title: String Theories on the Asymmetric Orbifolds with Twist-Untwist Intertwining Currents
# Keywords: ['the', 'leads', 'possess', 'twisted', 'examples']
# ----------------------------------------
# Paper ID: 9211129
# Title: Algebraically Special Class of Space-Times and (1+1)-Dimensional Field Theories
# Keywords: ['with', '2', 'are', 'discuss', 'description']
# ----------------------------------------
# Paper ID: 9207039
# Title: Current Algebra in Three Dimensions
# Keywords: ['algebra', 'the', 'Simons', 'Chern', 'of']
# ----------------------------------------
# Paper ID: 9209014
# Title: Free Boson Representation of $U_{q}(\hat{sl_{2}})$
# Keywords: ['hat', 'An', 'algebra', 'arbitrary', 'action']
# ----------------------------------------
# Paper ID: 9207011
# Title: Non-relativistic Fermions, Coadjoint Orbits of \winf\ and String Field Theory at $c=1$
# Keywords: ['two', 'infinite', 'The', 'method', 'for']
# ----------------------------------------
# Paper ID: 9211115
# Title: Generalising the staircase models
# Keywords: ['before', 'model', 'one', 'with', 'k']
# ----------------------------------------
# Paper ID: 9211101
# Title: \delta-expansion and self-consistent calculation
# Keywords: ['with', 'theories', 'compare', 'accurate', 'calculations']
# ----------------------------------------
# Paper ID: 9207005
# Title: Space-Time Symmetries of Quantized Tensionless Strings
# Keywords: ['a', 'conformally', 'but', 'ordinary', 'tension']
# ----------------------------------------
# Paper ID: 9209028
# Title: The radial gauge propagators in quantum gravity
# Keywords: ['and', 'In', 'gravity', 'the', 'propagating']
# ----------------------------------------
# Paper ID: 9204083
# Title: Two Dimensional Gauge Theories Revisited
# Keywords: ['however', 'proved', 'In', 'completely', '1']
# ----------------------------------------
# Paper ID: 9204097
# Title: Singular Vectors of the Virasoro Algebra
# Keywords: ['vectors', 'explain', 'amongst', 'the', 'Virasoro']
# ----------------------------------------
# Paper ID: 9210035
# Title: Influence Functionals and the Accelerating Detector
# Keywords: ['Hawking', 'solution', 'from', 'This', 'mechanics']
# ----------------------------------------
# Paper ID: 9204040
# Title: On the Moduli Space of the $T^6/Z_3$ Orbifold and Its Modular Group
# Keywords: ['embedding', 'an', 'expression', 'orbifold', 'given']
# ----------------------------------------
# Paper ID: 9203049
# Title: Path-Integral Measure of Linearized Gravity in Curved Spacetime
# Keywords: ['gravity', 'can', 'considered', 'transformation', 'The']
# ----------------------------------------
# Paper ID: 9212144
# Title: Diff(SIGMA) and Metrics from Hamiltonian-TQFT's in 2+1 Dimensions
# Keywords: ['space', 'of', 'obtained', 'constraint', 'Theories']
# ----------------------------------------
# Paper ID: 9212150
# Title: Dilogarithm identities, partitions and spectra in conformal field theory, I
# Keywords: ['of', 'between', 'theory', 'identities', 'Rogers']
# ----------------------------------------
# Paper ID: 9204054
# Title: Heisenberg XXZ Model and Quantum Galilei Group
# Keywords: ['spin', 'are', 'given', 'algebra', 'the']
# ----------------------------------------
# Paper ID: 9210021
# Title: Duality Symmetries from Non--Abelian Isometries in String Theories
# Keywords: ['this', 'dual', 'of', 'space', 'theory']
# ----------------------------------------
# Paper ID: 9210009
# Title: Quantum Affine Symmetry as Generalized Supersymmetry
# Keywords: ['of', 'elements', 'supersymmetric', 'The', 'written']
# ----------------------------------------
# Paper ID: 9203075
# Title: Current Algebra of WZNW Models at and away from Criticality
# Keywords: ['In', 'algebra', 'latter', 'this', 'theory']
# ----------------------------------------
# Paper ID: 9203061
# Title: Gravitational Phase Transitions and the Sine-Gordon Model
# Keywords: ['melts', 'field', 'of', 'A', 'cosmological']
# ----------------------------------------
# Paper ID: 9204068
# Title: Corner Transfer Matrices and Quantum Affine Algebras
# Keywords: ['infinite', 'the', 'representation', 'We', 'matrix']
# ----------------------------------------
# Paper ID: 9210025
# Title: Rogers dilogarithm in integrable systems
# Keywords: ['proceedings', 'dicuss', 'two', 'for', 'aspects']
# ----------------------------------------
# Paper ID: 9204050
# Title: Topological Gauged WZW Models and 2D Gravity
# Keywords: ['Suzuki', 'a', 'this', 'K', 'matter']
# ----------------------------------------
# Paper ID: 9212154
# Title: Lattice Topological Field Theory in Two Dimensions
# Keywords: ['are', 'given', 'perturbations', 'and', 'space']
# ----------------------------------------
# Paper ID: 9203059
# Title: Black Holes and Massive Remnants
# Keywords: ['this', 'mass', 'a', 'conundrum', 'of']
# ----------------------------------------
# Paper ID: 9212140
# Title: Conformal dynamics of quantum gravity with torsion
# Keywords: ['factor', 'investigated', 'dynamics', 'of', 'scalar']
# ----------------------------------------
# Paper ID: 9204044
# Title: Perturbation Theory for Antisymmetric Tensor Fields in Four Dimensions
# Keywords: ['of', 'theory', 'Perturbation', 'field', 'supersymmetric']
# ----------------------------------------
# Paper ID: 9210031
# Title: Charged String-like Solutions of Low-energy Heterotic String Theory
# Keywords: ['particular', 'solution', 'a', 'that', 'and']
# ----------------------------------------
# Paper ID: 9210019
# Title: On the quantisation of SU(2) magnetic monopole dynamics
# Keywords: ['system', 'of', 'monopole', 'that', 'quantisation']
# ----------------------------------------
# Paper ID: 9203065
# Title: Bethe Ansatz and Quantum Groups: The Light--Cone Approach. II. From RSOS($p+1$) models to $p-$restricted Sine--Gordon Field Theories
# Keywords: ['model', 'q', 'solve', 'by', 'quantum']
# ----------------------------------------
# Paper ID: 9203071
# Title: Moduli Corrections to Gravitational Couplings from String loops
# Keywords: ['calculation', 'N', 'string', 'to', 'gravity']
# ----------------------------------------
# Paper ID: 9206109
# Title: Maurer-Cartan forms and equations for two-dimensional superdiffeomorphisms
# Keywords: ['for', 'an', 'effective', 'forms', 'expressions']
# ----------------------------------------
# Paper ID: 9204078
# Title: Non-Critical Strings in Robertson-Walker Space Time
# Keywords: ['possible', 'of', 'dimensional', 'equations', 'the']
# ----------------------------------------
# Paper ID: 9204093
# Title: Review of W Strings
# Keywords: ['algebra', 'of', 'These', 'the', 'with']
# ----------------------------------------
# Paper ID: 9209010
# Title: Factorization and Discrete States in C=1 Superliouville Theory
# Keywords: ['are', 'algebra', 'c', 'structure', 'of']
# ----------------------------------------
# Paper ID: 9211139
# Title: Nonperturbative Conditions for Local Weyl Invariance on a Curved World Sheet
# Keywords: ['Also', 'to', 'establish', 'product', 'functions']
# ----------------------------------------
# Paper ID: 9209004
# Title: Group Theoretical Symmetries and Generalized Baecklund Transformations for Integrable Systems
# Keywords: ['also', 'the', 'for', 'generalized', 'invariance']
# ----------------------------------------
# Paper ID: 9207029
# Title: Conformal fields: a class of representations of Vect(N)
# Keywords: ['of', 'dimensional', 'studied', 'restrictions', 'conformal']
# ----------------------------------------
# Paper ID: 9207001
# Title: All Symmetries of Non-Einsteinian Gravity in $d =2$
# Keywords: ['should', 'between', 'so', 'transformations', 'one']
# ----------------------------------------
# Paper ID: 9211105
# Title: Cyclic monodromy matrices for sl(n) trigonometric R-matrices
# Keywords: ['studied', 'of', 'algebras', 'is', 'finite']
# ----------------------------------------
# Paper ID: 9211111
# Title: Quantum Inverse Scattering Method. Selected Topics
# Keywords: ['motion', 'A', 'given', 'Mathematics', 'are']
# ----------------------------------------
# Paper ID: 9209038
# Title: Functional determinant and Green functions for a fermionic gauge theory on the disk
# Keywords: ['associated', 'to', 'a', 'fermionic', 'with']
# ----------------------------------------
# Paper ID: 9207015
# Title: The full set of $c_n$-invariant factorized $S$-matrices
# Keywords: ['charges', 'to', 'Yangian', 's', 'representations']
# ----------------------------------------
# Paper ID: 9202031
# Title: Black Holes in Higher Derivative Gravity Theories
# Keywords: ['terms', 'anti', 'space', 'and', 'The']
# ----------------------------------------
# Paper ID: 9205038
# Title: Recent Developments in Classical and Quantum Theories of Connections, Including General Relativity
# Keywords: ['this', 'related', 'of', 'methods', 'theory']
# ----------------------------------------
# Paper ID: 9211059
# Title: A tour through N=2 strings
# Keywords: ['in', 'of', 'a', 'amplitude', 'possibility']
# ----------------------------------------
# Paper ID: 9202025
# Title: BRST Field Theory of Relativistic Particles
# Keywords: ['Polyakov', 'presented', 'generalized', 'field', 'In']
# ----------------------------------------
# Paper ID: 9211071
# Title: Conformal Symmetry and Universal Properties of Quantum Hall States
# Keywords: ['would', 'a', 'approach', 'for', 'cylinder']
# ----------------------------------------
# Paper ID: 9205004
# Title: No Mirror Symmetry in Landau-Ginzburg Spectra!
# Keywords: ['may', 'for', 'a', 'model', 'non']
# ----------------------------------------
# Paper ID: 9205010
# Title: A Proposal for $D>1$ Strings?
# Keywords: ['than', 'concerning', 'string', 'large', 'Some']
# ----------------------------------------
# Paper ID: 9211065
# Title: Minimal deformations of the commutative algebra and the linear group GL(n)
# Keywords: ['for', 'matrix', 'Q', 'corresponding', 'parameters']
# ----------------------------------------
# Paper ID: 9202019
# Title: D=0 Matrix Model as Conjugate Field Theory
# Keywords: ['The', 'modification', 'of', 'theory', 'model']
# ----------------------------------------
# Paper ID: 9210151
# Title: Zero-Modes, Covariant Anomaly Counterparts and Reducible Connections in Topological Yang-Mills Theory
# Keywords: ['non', 'number', 'from', 'anomalies', 'space']
# ----------------------------------------
# Paper ID: 9212020
# Title: Non-Extreme and Ultra-Extreme Domain Walls and Their Global Space-Times
# Keywords: ['space', 'that', 'the', 'non', 'walls']
# ----------------------------------------
# Paper ID: 9206055
# Title: Classical and Quantum Production of Cornucopions At Energies Below $10^{18}$ GeV
# Keywords: ['particles', 'argue', 'general', 'a', 'for']
# ----------------------------------------
# Paper ID: 9208078
# Title: Electric-Magnetic Duality and Supersymmetry in Stringy Black Holes
# Keywords: ['of', 'symmetry', '1', 'we', 'present']
# ----------------------------------------
# Paper ID: 9206041
# Title: S-matrices for Perturbed N=2 Superconformal Field Theory from quantum groups
# Keywords: ['k', 'theory', 'to', 'h', 'matrices']
# ----------------------------------------
# Paper ID: 9212034
# Title: Do Black Holes Form?
# Keywords: ['unstable', 'is', 'been', 'of', 'one']
# ----------------------------------------
# Paper ID: 9210145
# Title: Generalized Spin Systems and $\sigma$--Models
# Keywords: ['space', 'limits', 'The', 'equations', 'generalization']
# ----------------------------------------
# Paper ID: 9201048
# Title: The Chern-Simons Source as a Conformal Family and Its Vertex Operators
# Keywords: ['straightforward', 'gives', 'from', 'localized', 'spin']
# ----------------------------------------
# Paper ID: 9201060
# Title: Lax Pair Formulation of the W-gravity Theories in two Dimensions
# Keywords: ['are', 'for', 'a', 'w_2', 'gravity']
# ----------------------------------------
# Paper ID: 9206069
# Title: Two Dimensional String Theory And Black Holes
# Keywords: ['that', 'two', 'question', 'interest', 'theory']
# ----------------------------------------
# Paper ID: 9208044
# Title: Conformal Matrix Models as an Alternative to Conventional Multi-Matrix Models
# Keywords: ['KP', 'c', 'one', 'description', 'so']
# ----------------------------------------
# Paper ID: 9212008
# Title: Extending the Barnes-Rivers Operators to D=3 Topological Gravity
# Keywords: ['3', 'operators', 'account', 'of', 'gravity']
# ----------------------------------------
# Paper ID: 9208050
# Title: Remarks Concerning Polyakov's Conjecture for the 3D Ising Model and the Hierarchical Approximation
# Keywords: ['model', 'proposed', 'to', 'approximation', 'terms']
# ----------------------------------------
# Paper ID: 9201074
# Title: Black Hole Evaporation in 1+1 Dimensions
# Keywords: ['The', 'and', 'in', 'singularity', 'studied']
# ----------------------------------------
# Paper ID: 9206096
# Title: On Two-Current Realization of KP Hierarchy
# Keywords: ['A', 'given', 'of', 'structure', 'W']
# ----------------------------------------
# Paper ID: 9206082
# Title: BRS Operators and Covariant Derivatives in Loop Space for P-Branes Coupled to Yang-Mills
# Keywords: ['is', 'which', 'and', 'commutes', 'a']
# ----------------------------------------
# Paper ID: 9206083
# Title: Fitting the Quark and Lepton Masses in String Theories
# Keywords: ['fit', 'on', 'that', 'describe', 'a']
# ----------------------------------------
# Paper ID: 9206097
# Title: The regularized BRST Jacobian of pure Yang-Mills theory
# Keywords: ['Naively', 'general', 'the', 'Tr', 'constants']
# ----------------------------------------
# Paper ID: 9208051
# Title: Differential Equations in Special Kahler Geometry
# Keywords: ['Italy', 'the', 'in', 'of', 'string']
# ----------------------------------------
# Paper ID: 9212009
# Title: Spontaneous Symmetry Breaking of phi4(1+1) in Light Front Field Theory
# Keywords: ['phase', 'energy', 'in', 'equal', '3']
# ----------------------------------------
# Paper ID: 9201075
# Title: Topology change in ISO(2,1) Chern-Simons gravity
# Keywords: ['Euler', 'SO', 'the', 'space', '2']
# ----------------------------------------
# Paper ID: 9201061
# Title: Are Horned Particles the Climax of Hawking Evaporation?
# Keywords: ['gravity', 'proposal', 'However', 'can', 'a']
# ----------------------------------------
# Paper ID: 9208045
# Title: Large-N Reduction, Master Field and Loop Equations in Kazakov-Migdal Model
# Keywords: ['those', 'a', 'equations', 'model', 'twisting']
# ----------------------------------------
# Paper ID: 9206068
# Title: Uniqueness of the Axionic Kerr Black Hole
# Keywords: ['at', 'of', 'hole', 'it', 'angle']
# ----------------------------------------
# Paper ID: 9212035
# Title: Cosmological Multi-Black Hole Solutions
# Keywords: ['however', 'is', 'The', 'in', 'Einstein']
# ----------------------------------------
# Paper ID: 9206040
# Title: Higher Dimensional Classical W-Algebras
# Keywords: ['that', 'is', 'dimensional', 'the', '1']
# ----------------------------------------
# Paper ID: 9201049
# Title: Light-Cone Gauge for 1+1 Strings
# Keywords: ['Moody', 'of', 'symmetry', 'value', 'Lorentz']
# ----------------------------------------
# Paper ID: 9210150
# Title: Bicovariant Quantum Algebras and Quantum Lie Algebras
# Keywords: ['we', 'a', 'case', 'from', 'algebra']
# ----------------------------------------
# Paper ID: 9208079
# Title: Free Field Representation of Quantum Affine Algebra U_q(\hat{sl}_2)
# Keywords: ['algebra', 'for', 'bosonic', 'realization', 'an']
# ----------------------------------------
# Paper ID: 9206054
# Title: On the amplitudes for non-critical n=2 supuerstrings
# Keywords: ['1', 'the', 'compute', 'cases', 'that']
# ----------------------------------------
# Paper ID: 9212021
# Title: Magnetic Fields and Passive Scalars in Polyakov's Conformal Turbulence
# Keywords: ['field', 'a', 'In', 'not', 'energies']
# ----------------------------------------
# Paper ID: 9211064
# Title: Infinite Tension Strings at D>1
# Keywords: ['simple', 'From', 'considered', 'to', 'an']
# ----------------------------------------
# Paper ID: 9205011
# Title: Of CP and other Gauge Symmetries in String Theory
# Keywords: ['principle', 'non', 'violating', 'string', 'is']
# ----------------------------------------
# Paper ID: 9202018
# Title: Jones Polynomials for Intersecting Knots as Physical States of Quantum Gravity
# Keywords: ['Chern', 'This', 'with', 'a', 'state']
# ----------------------------------------
# Paper ID: 9205005
# Title: Comments on Unitarity in the Antifield Formalism
# Keywords: ['formalism', 'proof', 'the', 'gauge', 'fixed']
# ----------------------------------------
# Paper ID: 9211070
# Title: Self-Dual Yang-Mills and the Hamiltonian Structures of Integrable Systems
# Keywords: ['to', 'present', 'that', 'hierarchy', 'dual']
# ----------------------------------------
# Paper ID: 9211058
# Title: The Phase Structure of Strings with Extrinsic Curvature
# Keywords: ['the', 'discuss', 'surfaces', 'analyze', 'behaviour']
# ----------------------------------------
# Paper ID: 9202024
# Title: Spinning Braid Group Representation and the Fractional Quantum Hall Effect
# Keywords: ['from', 'in', 'excitations', 'Hamiltonian', 'our']
# ----------------------------------------
# Paper ID: 9202030
# Title: Stochastic Quantization of the Chern-Simons Theory
# Keywords: ['a', 'showing', 'theory', 'and', 'regularization']
# ----------------------------------------
# Paper ID: 9205039
# Title: Constant Solutions of Reflection Equations and Quantum Groups
# Keywords: ['we', 'equations', 'various', 'to', 'given']
# ----------------------------------------
# Paper ID: 9211110
# Title: Low-Energy Effective Action of Superstring Theory
# Keywords: ['presented', 'progress', 'In', 'physics', 'Yukawa']
# ----------------------------------------
# Paper ID: 9207014
# Title: A Note on ``Anomalous" Chiral Gauge Theories
# Keywords: ['dimensional', 'to', 'But', 'theory', '1']
# ----------------------------------------
# Paper ID: 9209039
# Title: Quantum Mechanics with Explicit Time Dependence
# Keywords: ['exactly', 'an', 'oscillator', 'of', 'model']
# ----------------------------------------
# Paper ID: 9211104
# Title: The Non-perturbative Canonical Quantization of the N=1 Supergravity
# Keywords: ['function', 'of', 'universe', 'using', 'the']
# ----------------------------------------
# Paper ID: 9207028
# Title: Vanishing of the Cosmological Constant in Stabilized Quantum Gravity
# Keywords: ['stochastic', 'except', 'the', 'zeroth', 'than']
# ----------------------------------------
# Paper ID: 9209005
# Title: Two-Loop Analysis of Non-abelian Chern-Simons Theory
# Keywords: ['regularization', 'for', 'coupled', 'we', 'a']
# ----------------------------------------
# Paper ID: 9209011
# Title: The Complete Structure of the Cohomology Ring and Associated Symmetries in $D=2$ String Theory
# Keywords: ['b', 'of', 'symmetry', 'This', 'determine']
# ----------------------------------------
# Paper ID: 9211138
# Title: Fusion potentials I
# Keywords: ['an', 'ring', 'theory', 'with', 'variables']
# ----------------------------------------
# Paper ID: 9204086
# Title: Quantum Group $\sigma$ Models
# Keywords: ['2', 'represented', 'q', 'Field', 'with']
# ----------------------------------------
# Paper ID: 9204092
# Title: Additional symmetries of KP, Grassmannian, and the string equation
# Keywords: ['invariant', 'else', 'a', 'of', 'This']
# ----------------------------------------
# Paper ID: 9206108
# Title: Nonlinear Realisations of $w_{1+\infty}$
# Keywords: ['structure', 'a', 'transformation', 'for', 'algebra']
# ----------------------------------------
# Paper ID: 9203070
# Title: Finiteness and anomalies in (4,0) supersymmetric sigma models
# Keywords: ['extended', 'In', 'finite', 'two', 'required']
# ----------------------------------------
# Paper ID: 9204079
# Title: String Effective Actions and Cosmological Stability of Scalar Potentials
# Keywords: ['studied', 'In', 'for', 'unstable', 'one']
# ----------------------------------------
# Paper ID: 9210018
# Title: The Cosmological Kibble Mechanism in the Laboratory: String Formation in Liquid Crystals
# Keywords: ['2', 'measured', 'a', 'of', 'This']
# ----------------------------------------
# Paper ID: 9203064
# Title: New Approach to Thermal Bethe Ansatz
# Keywords: ['theory', 'to', 'temperatures', '70', 'equation']
# ----------------------------------------
# Paper ID: 9212141
# Title: U_q(N) Gauge Theories
# Keywords: ['generalization', 'gauge', 'under', 'we', 'construction']
# ----------------------------------------
# Paper ID: 9210030
# Title: Twisted Sector Yukawa Couplings for the $Z_3\times Z_3$ Orbifold
# Keywords: ['couplings', 'the', 'sectors', 'moduli', 'of']
# ----------------------------------------
# Paper ID: 9204045
# Title: Non-Renormalization Properties of the Chern-Simons Action Coupled to Matter
# Keywords: ['Ward', 'an', 'gauge', 'with', 'corrections']
# ----------------------------------------
# Paper ID: 9204051
# Title: String amplitudes in arbitrary dimensions
# Keywords: ['of', 'the', 'dimensional', 'gravity', 'dressed']
# ----------------------------------------
# Paper ID: 9210024
# Title: Quantum Group Gauge Theory on Classical Spaces
# Keywords: ['for', 'In', 'Our', 'new', 'than']
# ----------------------------------------
# Paper ID: 9203058
# Title: World-Sheet Supersymmetry Without Contact Terms
# Keywords: ['that', 'In', 'terms', 'corrections', 'geometry']
# ----------------------------------------
# Paper ID: 9212155
# Title: Harmonic space and quaternionic manifolds
# Keywords: ['As', '2', 'The', 'space', 'geometry']
# ----------------------------------------
# Paper ID: 9204047
# Title: Strong Coupling Qed Breaks Chiral Symmetry
# Keywords: ['a', 'space', 'spin', 'the', 'antiferromagnetic']
# ----------------------------------------
# Paper ID: 9210032
# Title: q-deformed lattice gauge theory and 3-manifold invariants
# Keywords: ['gives', 'model', 'with', 'invariant', 'A']
# ----------------------------------------
# Paper ID: 9212143
# Title: Hidden geometrical structures in integrable models
# Keywords: ['described', 'of', 'systems', 'material', 'purely']
# ----------------------------------------
# Paper ID: 9212157
# Title: Paragrassmann Extensions of the Virasoro Algebra
# Keywords: ['proposed', 'the', 'paragrassmann', 'Virasoro', 'algebras']
# ----------------------------------------
# Paper ID: 9210026
# Title: Faddeev-Popov method for anomalous quasigroups
# Keywords: ['deal', 'of', 'obtained', 'theories', 'An']
# ----------------------------------------
# Paper ID: 9204053
# ...
# ----------------------------------------
# Paper ID: 9210039
# Title: The universal R-matrix and its associated quantum algebra as functionals of the classical r-matrix: the $sl_{2}$ case
# Keywords: ['envelopping', 'and', 'algebra', 'in', 'quantum']
# ----------------------------------------
# Paper ID: 9203045
# Title: Results of the classification of superconformal algebras in two dimensions
# Keywords: ['4', 'In', 'A', 'and', 'superalgebra']
# ----------------------------------------
# Paper ID: 9212148
# Title: Some New/Old Approaches to QCD
# Keywords: ['an', 'This', 'on', 'discuss', 'Villa']
# ----------------------------------------
# Paper ID: 9204064
# Title: Diagonalization of the XXZ Hamiltonian by Vertex Operators
# Keywords: ['number', 'structure', 'from', 'algebras', 'matrix']
# ----------------------------------------
# Paper ID: 9210011
# Title: Gauge Theories on a Cylinder
# Keywords: ['few', 'a', 'typos', 'error', 'and']
# ----------------------------------------
# Paper ID: 9210005
# Title: Ray-Singer Torsion, Topological field theories and the Riemann zeta function at s=3
# Keywords: ['ordinary', 'for', 'a', '6', 'functions']
# ----------------------------------------
# Paper ID: 9204070
# Title: Gravitational and Schwinger model anomalies: how far can the analogy go?
# Keywords: ['gravity', 'present', 'It', 'of', 'Analogy']
# ----------------------------------------
# Paper ID: 9203079
# Title: Weaving a classical geometry with quantum threads
# Keywords: ['quantized', 'obtained', 'but', '2', 'scale']
# ----------------------------------------
# Paper ID: 9206101
# Title: Self-Dual Supergravity Theories in 2+2 Dimensions
# Keywords: ['dual', 'an', 'torsion', 'following', 'of']
# ----------------------------------------
# Paper ID: 9210013
# Title: Vacuum energy on orbifold factors of spheres
# Keywords: ['but', 'given', 'generalised', 'in', 'several']
# ----------------------------------------
# Paper ID: 9204066
# Title: Syncyclons or Solitonic Signals from Extra Dimensions
# Keywords: ['in', '2', 'space', 'fermion', 'K']
# ----------------------------------------
# Paper ID: 9206103
# Title: The Sum over Topologies in Three-Dimensional Euclidean Quantum Gravity
# Keywords: ['three', 'from', 'sum', 'implications', 'topologically']
# ----------------------------------------
# Paper ID: 9204072
# Title: Quantum Emission from Two-Dimensional Black Holes
# Keywords: ['to', 'in', 'computed', 'is', 'effect']
# ----------------------------------------
# Paper ID: 9210007
# Title: Virasoro Representations on Fusion Graphs
# Keywords: ['model', 'isomorphic', 'c', 'irreducible', 'to']
# ----------------------------------------
# Paper ID: 9203053
# Title: Combinatorial and topological phase structure of non-perturbative n-dimensional quantum gravity
# Keywords: ['of', 'geometries', 'under', 'dimensional', 'a']
# ----------------------------------------
# Paper ID: 9203047
# Title: Anyons in discrete gauge theories with Chern-Simons terms
# Keywords: ['labelled', '1', 'theory', 'physically', 'in']
# ----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 40
#      38 for paper in data:
#      39     abstract = paper.get("abstract", "")
# ---> 40     keywords = extract_keywords(abstract)
#      41     print(f"Paper ID: {paper['paper_id']}")
#      42     print(f"Title: {paper['title']}")
#
# Cell In[2], line 16, in extract_keywords(text, top_n)
#      13 unique_words = list(set(words))
#      15 # 生成每个词的向量
# ---> 16 embeddings = model.encode(unique_words)
#      18 # 聚类
#      19 if len(unique_words) < top_n:
#
# File /opt/anaconda3/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py:685, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, **kwargs)
#     682 features.update(extra_features)
#     684 with torch.no_grad():
# --> 685     out_features = self.forward(features, **kwargs)
#     686     if self.device.type == "hpu":
#     687         out_features = copy.deepcopy(out_features)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py:758, in SentenceTransformer.forward(self, input, **kwargs)
#     756     module_kwarg_keys = self.module_kwargs.get(module_name, [])
#     757     module_kwargs = {key: value for key, value in kwargs.items() if key in module_kwarg_keys}
# --> 758     input = module(input, **module_kwargs)
#     759 return input
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /opt/anaconda3/lib/python3.12/site-packages/sentence_transformers/models/Transformer.py:442, in Transformer.forward(self, features, **kwargs)
#     435 """Returns token_embeddings, cls_token"""
#     436 trans_features = {
#     437     key: value
#     438     for key, value in features.items()
#     439     if key in ["input_ids", "attention_mask", "token_type_ids", "inputs_embeds"]
#     440 }
# --> 442 outputs = self.auto_model(**trans_features, **kwargs, return_dict=True)
#     443 token_embeddings = outputs[0]
#     444 features["token_embeddings"] = token_embeddings
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /opt/anaconda3/lib/python3.12/site-packages/transformers/models/bert/modeling_bert.py:1142, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1135 # Prepare head mask if needed
#    1136 # 1.0 in head_mask indicate we keep the head
#    1137 # attention_probs has shape bsz x n_heads x N x N
#    1138 # input head_mask has shape [num_heads] or [num_hidden_layers x num_heads]
#    1139 # and head_mask is converted to shape [num_hidden_layers x batch x num_heads x seq_length x seq_length]
#    1140 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# -> 1142 encoder_outputs = self.encoder(
#    1143     embedding_output,
#    1144     attention_mask=extended_attention_mask,
#    1145     head_mask=head_mask,
#    1146     encoder_hidden_states=encoder_hidden_states,
#    1147     encoder_attention_mask=encoder_extended_attention_mask,
#    1148     past_key_values=past_key_values,
#    1149     use_cache=use_cache,
#    1150     output_attentions=output_attentions,
#    1151     output_hidden_states=output_hidden_states,
#    1152     return_dict=return_dict,
#    1153 )
#    1154 sequence_output = encoder_outputs[0]
#    1155 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /opt/anaconda3/lib/python3.12/site-packages/transformers/models/bert/modeling_bert.py:695, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     684     layer_outputs = self._gradient_checkpointing_func(
#     685         layer_module.__call__,
#     686         hidden_states,
#    (...)
#     692         output_attentions,
#     693     )
#     694 else:
# --> 695     layer_outputs = layer_module(
#     696         hidden_states,
#     697         attention_mask,
#     698         layer_head_mask,
#     699         encoder_hidden_states,
#     700         encoder_attention_mask,
#     701         past_key_value,
#     702         output_attentions,
#     703     )
#     705 hidden_states = layer_outputs[0]
#     706 if use_cache:
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /opt/anaconda3/lib/python3.12/site-packages/transformers/models/bert/modeling_bert.py:585, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     573 def forward(
#     574     self,
#     575     hidden_states: torch.Tensor,
#    (...)
#     582 ) -> Tuple[torch.Tensor]:
#     583     # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     584     self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 585     self_attention_outputs = self.attention(
#     586         hidden_states,
#     587         attention_mask,
#     588         head_mask,
#     589         output_attentions=output_attentions,
#     590         past_key_value=self_attn_past_key_value,
#     591     )
#     592     attention_output = self_attention_outputs[0]
#     594     # if decoder, the last output is tuple of self-attn cache
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /opt/anaconda3/lib/python3.12/site-packages/transformers/models/bert/modeling_bert.py:515, in BertAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     505 def forward(
#     506     self,
#     507     hidden_states: torch.Tensor,
#    (...)
#     513     output_attentions: Optional[bool] = False,
#     514 ) -> Tuple[torch.Tensor]:
# --> 515     self_outputs = self.self(
#     516         hidden_states,
#     517         attention_mask,
#     518         head_mask,
#     519         encoder_hidden_states,
#     520         encoder_attention_mask,
#     521         past_key_value,
#     522         output_attentions,
#     523     )
#     524     attention_output = self.output(self_outputs[0], hidden_states)
#     525     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /opt/anaconda3/lib/python3.12/site-packages/transformers/models/bert/modeling_bert.py:440, in BertSdpaSelfAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     432 # We dispatch to SDPA's Flash Attention or Efficient kernels via this `is_causal` if statement instead of an inline conditional assignment
#     433 # in SDPA to support both torch.compile's dynamic shapes and full graph options. An inline conditional prevents dynamic shapes from compiling.
#     434 # The tgt_len > 1 is necessary to match with AttentionMaskConverter.to_causal_4d that does not create
#     435 # a causal mask in case tgt_len == 1.
#     436 is_causal = (
#     437     True if self.is_decoder and not is_cross_attention and attention_mask is None and tgt_len > 1 else False
#     438 )
# --> 440 attn_output = torch.nn.functional.scaled_dot_product_attention(
#     441     query_layer,
#     442     key_layer,
#     443     value_layer,
#     444     attn_mask=attention_mask,
#     445     dropout_p=self.dropout_prob if self.training else 0.0,
#     446     is_causal=is_causal,
#     447 )
#     449 attn_output = attn_output.transpose(1, 2)
#     450 attn_output = attn_output.reshape(bsz, tgt_len, self.all_head_size)
#
# KeyboardInterrupt:

# %%
from keybert import KeyBERT
import json

# 准备摘要数据（模拟你有100条）
with open("papers_standardized.json", "r") as f:
    data = json.load(f)

# 只提取前一百条摘要
abstracts = [paper.get("abstract", "") for paper in data[:10]]

# 拼接所有摘要
all_text = " ".join(abstracts)

# 初始化 KeyBERT 模型
kw_model = KeyBERT(model='all-MiniLM-L6-v2')

# 提取关键词
keywords = kw_model.extract_keywords(
    all_text,
    top_n=20,
    stop_words='english',
    use_maxsum=True,
    nr_candidates=50
)

# 只提取关键词词汇部分
keyword_list = [kw[0] for kw in keywords]
keyword_list
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 18
#      15 kw_model = KeyBERT(model='all-MiniLM-L6-v2')
#      17 # 提取关键词
# ---> 18 keywords = kw_model.extract_keywords(
#      19     all_text,
#      20     top_n=20,
#      21     stop_words='english',
#      22     use_maxsum=True,
#      23     nr_candidates=50
#      24 )
#      26 # 只提取关键词词汇部分
#      27 keyword_list = [kw[0] for kw in keywords]
#
# File /opt/anaconda3/lib/python3.12/site-packages/keybert/_model.py:235, in KeyBERT.extract_keywords(self, docs, candidates, keyphrase_ngram_range, stop_words, top_n, min_df, use_maxsum, use_mmr, diversity, nr_candidates, vectorizer, highlight, seed_keywords, doc_embeddings, word_embeddings, threshold)
#     233 # Max Sum Distance
#     234 elif use_maxsum:
# --> 235     keywords = max_sum_distance(
#     236         doc_embedding,
#     237         candidate_embeddings,
#     238         candidates,
#     239         top_n,
#     240         nr_candidates,
#     241     )
#     243 # Cosine-based keyword extraction
#     244 else:
#     245     distances = cosine_similarity(doc_embedding, candidate_embeddings)
#
# File /opt/anaconda3/lib/python3.12/site-packages/keybert/_maxsum.py:51, in max_sum_distance(doc_embedding, word_embeddings, words, top_n, nr_candidates)
#      49 candidate = None
#      50 for combination in itertools.combinations(range(len(words_idx)), top_n):
# ---> 51     sim = sum([candidates[i][j] for i in combination for j in combination if i != j])
#      52     if sim < min_sim:
#      53         candidate = combination
#
# KeyboardInterrupt:
